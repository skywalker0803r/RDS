# %%
import pandas as pd
import requests
url = 'https://gist.githubusercontent.com/skywalker0803r/5e9725321f403e2f6f14122165d7b3fd/raw/5108b1e7c76daa103ed8a6e34556145d4d0d28b6/Rawdataencryption.py'
exec(requests.get(url).text)
feed = Rawdataencryption('RDS2品質-20220520.xlsx','Feed')
feed
# Out:
#      單元   RDS2  RDS2.1  RDS2.2  RDS2.3  RDS2.4  RDS2.5  RDS2.6  RDS2.7  \
# 0   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ..   ..    ...     ...     ...     ...     ...     ...     ...     ...
# 306 NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 307 NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 308 NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 309 NaN  363.4   433.4   466.8     NaN   549.0     NaN   623.2     NaN
# 310 NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      RDS2.8  ...   RDS2.18   RDS2.19    RDS2.20  RDS2.21  RDS2.22  RDS2.23  \
# ...

# %%
ProductDSLGO = Rawdataencryption('RDS2品質-20220520.xlsx','Product-DSLGO')
ProductDSLGO
# Out:
#      單元   RDS2  RDS2.1  RDS2.2  RDS2.3  RDS2.4  RDS2.5  RDS2.6  RDS2.7  \
# 0   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ..   ..    ...     ...     ...     ...     ...     ...     ...     ...
# 306 NaN  337.5   362.4   372.9   389.2   402.2     NaN   424.7   434.4
# 307 NaN  296.1   367.7   376.1   391.5   404.4     NaN   425.8   435.2
# 308 NaN  340.8   368.7   375.1   391.0   403.7     NaN   424.0   432.5
# 309 NaN  337.7   370.6   376.7   392.6   404.7     NaN   425.1   434.1
# 310 NaN  339.4   369.6   377.2   392.3   404.7     NaN   425.8   434.7
#
#      RDS2.8  ...  RDS2.15    RDS2.16  RDS2.17    RDS2.18    RDS2.19   RDS2.20  \
# ...

# %%
ProductDSAR = Rawdataencryption('RDS2品質-20220520.xlsx','Product-DSAR')
ProductDSAR
# Out:
#      單元   RDS2  RDS2.1  RDS2.2  RDS2.3  RDS2.4  RDS2.5  RDS2.6  RDS2.7  \
# 0   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4   NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ..   ..    ...     ...     ...     ...     ...     ...     ...     ...
# 306 NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 307 NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 308 NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 309 NaN  457.2   508.4   524.6   549.6   571.8   598.2   625.4   654.2
# 310 NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      RDS2.8  ...  RDS2.14  RDS2.15   RDS2.16  RDS2.17   RDS2.18  RDS2.19  \
# ...

# %%
OP = Rawdataencryption('RDS2品質-20220520.xlsx','OP')
OP
# Out:
#      Unnamed: 0      RDS2    RDS2.1    RDS2.2     RDS2.3    RDS2.4    RDS2.5  \
# 0           NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 3           NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 4           NaN       NaN       NaN       NaN        NaN       NaN       NaN
# ..          ...       ...       ...       ...        ...       ...       ...
# 306         NaN  578.9728  490.0635  489.6590  489.86125  501.6363  501.8767
# 307         NaN  582.8199  490.1206  489.7996  489.96010  501.5562  501.7037
# 308         NaN  582.0358  490.1164  489.4867  489.80155  501.3816  501.6660
# 309         NaN  581.8906  490.1538  489.4843  489.81905  501.3670  501.6917
# 310         NaN  582.4168  490.1169  489.5409  489.82890  501.3406  501.6246
#
# ...

# %%
feed.to_csv('feed.csv')
ProductDSLGO.to_csv('ProductDSLGO.csv')
ProductDSAR.to_csv('ProductDSAR.csv')
OP.to_csv('OP.csv')
